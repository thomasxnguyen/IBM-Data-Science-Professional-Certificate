# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Thomas Nguyen**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because I enjoy solving complex problems.*

# %% [markdown]
# ### The following code is a simple addition problem.

# %%
print(1+1)
# Out:
# 2

# %% [markdown]
# **Horizontal rule**
# ***
# **Bulleted List**
#
# * one
# * two
# * three
#
# **Numbered List**
#
# 1. one
# 2. two
# 3. three
